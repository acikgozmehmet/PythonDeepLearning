# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
(train_images, train_labels), (test_images, test_labels)= mnist.load_data()
train_images.shape, test_images.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
print(train_images.shape[1:])
dimData = np.prod(train_images.shape[1:])
dimData
# Out:
# (28, 28)
# 784

# %%
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data  =  test_images.reshape(test_images.shape[0], dimData)
train_data.shape, test_data.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
# scale values between 0 and 1
train_data /=255.0
test_data /=255.0

# %%
#change the labels from integer to one-hot encoding. 
# to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# %%
#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))

# For 3rd question
# model.add(Dense(512, activation='tanh'))
# model.add(Dense(128, activation='relu'))
# model.add(Dense(64, activation='sigmoid'))

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.3880 - accuracy: 0.8976 - val_loss: 0.1449 - val_accuracy: 0.9582
# Epoch 2/10
# 235/235 [==============================] - 9s 38ms/step - loss: 0.1157 - accuracy: 0.9665 - val_loss: 0.0921 - val_accuracy: 0.9732
# Epoch 3/10
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0740 - accuracy: 0.9787 - val_loss: 0.0950 - val_accuracy: 0.9738
# Epoch 4/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0537 - accuracy: 0.9843 - val_loss: 0.0957 - val_accuracy: 0.9725
# Epoch 5/10
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0398 - accuracy: 0.9881 - val_loss: 0.0748 - val_accuracy: 0.9793
# Epoch 6/10
# 235/235 [==============================] - 10s 44ms/step - loss: 0.0320 - accuracy: 0.9904 - val_loss: 0.0750 - val_accuracy: 0.9795
# Epoch 7/10
# 235/235 [==============================] - 10s 41ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.1021 - val_accuracy: 0.9735
# Epoch 8/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 0.0828 - val_accuracy: 0.9777
# Epoch 9/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0915 - val_accuracy: 0.9793
# Epoch 10/10
# 235/235 [==============================] - 10s 41ms/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 0.0821 - val_accuracy: 0.9811

# %%
[test_loss, test_acc] = model.evaluate(test_data, test_labels_one_hot)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc))
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0821 - accuracy: 0.9811
# Evaluation result on Test Data : Loss = 0.0820518359541893, accuracy = 0.9811000227928162

# %%
# question 1
plt.figure(figsize=(10,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# using history object for plotting loss
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# question 2
plt.imshow(test_images[15, :, :], cmap='gray')
plt.title('The number : {}'.format(test_labels[0]))
plt.show()

# %%
predict_test = model.predict_classes(test_data[[15], :])
print("The prediction of the 15th in the test dataset is: ", predict_test)
#predict_test.argmax()
# Out:
# The prediction of the 15th in the test dataset is:  [5]

# %%
[test_loss, test_acc] = model.evaluate(test_data, test_labels_one_hot)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc))
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0812 - accuracy: 0.9819
# Evaluation result on Test Data : Loss = 0.08121736347675323, accuracy = 0.9818999767303467

# %%
from tensorflow import keras
#keras.utils.plot_model(model, 'model.png')
keras.utils.plot_model(model, 'model_shapes.png', show_shapes=True)
